# %% [markdown]
# # Load Results

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from method import  *

f = open('hb_win200_sam1_ceemdan_arima_gru.pkl', 'rb')
_, pred_ceemdan_gru, real = pickle.load(f)
f.close()

f = open('hb_win200_sam1_ceemdan_arima_tcn.pkl', 'rb')
_, pred_ceemdan_tcn, _ = pickle.load(f)
f.close()

f = open('hb_win200_sam1_ssa_arima_gru.pkl', 'rb')
_, pred_ssa_gru, _ = pickle.load(f)
f.close()

f = open('hb_win200_sam1_ssa_arima_tcn.pkl', 'rb')
_, pred_ssa_tcn, _ = pickle.load(f)
f.close()

# %%
print(rmse( , ))

plot_start = 1500
plot_end = 1600
y_true = real[plot_start:plot_end]
y_pred = np.sum(pred_ceemdan_gru, axis=0)[plot_start:plot_end]
print(rmse( , ))

plt.figure()
plt.plot(y_true, label='true')
plt.plot(np.sum(pred_ceemdan_gru, axis=0)[plot_start:plot_end])
plt.plot(np.sum(pred_ceemdan_tcn, axis=0)[plot_start:plot_end])
plt.plot(np.sum(pred_ssa_gru, axis=0)[plot_start:plot_end])
plt.plot(np.sum(pred_ssa_tcn, axis=0)[plot_start:plot_end])
